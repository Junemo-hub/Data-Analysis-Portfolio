# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(style="whitegrid")  # 보기 좋은 테마
df = pd.read_csv("../data/creditcard.csv")  # 파일 경로 확인 필수

# %%
df['LogAmount'] = np.log1p(df['Amount'])

# %%
df['Hour'] = (df['Time'] // 3600) % 24

# %%
df['IsBigAmount'] = (df['Amount'] > 2000).astype(int)

# %%
df['V1_V2'] = df['V1'] * df['V2']

# %%
df.drop(['Time', 'Amount'], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V24       V25       V26       V27  \
# 0  0.098698  0.363787  0.090794  ...  0.066928  0.128539 -0.189115  0.133558
# 1  0.085102 -0.255425 -0.166974  ... -0.339846  0.167170  0.125895 -0.008983
# 2  0.247676 -1.514654  0.207643  ... -0.689281 -0.327642 -0.139097 -0.055353
# 3  0.377436 -1.387024 -0.054952  ... -1.175575  0.647376 -0.221929  0.062723
# 4 -0.270533  0.817739  0.753074  ...  0.141267 -0.206010  0.502292  0.219422
#
#         V28  Class  LogAmount  Hour  IsBigAmount     V1_V2
# 0 -0.021053      0   5.014760   0.0            0  0.098968
# 1  0.014724      0   1.305626   0.0            0  0.317214
# 2 -0.059752      0   5.939276   0.0            0  1.820416
# 3  0.061458      0   4.824306   0.0            0  0.178979
# 4  0.215153      0   4.262539   0.0            0 -1.016624
#
# [5 rows x 33 columns]
